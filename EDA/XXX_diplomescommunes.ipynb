# %%
import pandas as pd
# Out:
# /tmp/ipykernel_2470/4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv('diplomescommunes.csv')
df.shape
# Out:
# /tmp/ipykernel_2470/3705305927.py:1: DtypeWarning: Columns (0,2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('diplomescommunes.csv')
# (37985, 1163)

# %%
df.columns
# Out:
# Index(['dep', 'nomdep', 'codecommune', 'nomcommune', 'nodiph1962', 'bach1962',
#        'suph1962', 'nodipf1962', 'bacf1962', 'supf1962',
#        ...
#        'perbac1955', 'persup1955', 'perbac1956', 'persup1956', 'perbac1957',
#        'persup1957', 'perbac1958', 'persup1958', 'perbac1959', 'persup1959'],
#       dtype='object', length=1163)

# %%
df.isna().sum()
# Out:
# dep              0
# nomdep         243
# codecommune      0
# nomcommune       0
# nodiph1962     257
#               ...
# persup1957       0
# perbac1958       0
# persup1958       0
# perbac1959       0
# persup1959       0
# Length: 1163, dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.head()
# Out:
#   dep nomdep codecommune             nomcommune  nodiph1962  bach1962  \
# 0   1    AIN        1001  ABERGEMENT-CLEMENCIAT       121.0       4.0
# 1   1    AIN        1002    ABERGEMENT-DE-VAREY        40.0       0.0
# 2   1    AIN        1003               AMAREINS        32.0       0.0
# 3   1    AIN        1004      AMBERIEU-EN-BUGEY      2241.0      89.0
# 4   1    AIN        1005    AMBERIEUX-EN-DOMBES       181.0       0.0
#
#    suph1962  nodipf1962  bacf1962  supf1962  ...  perbac1955  persup1955  \
# 0       0.0       116.0       0.0       2.0  ...    0.263747    0.258736
# 1       2.0        19.0       0.0       0.0  ...    0.263809    0.642062
# 2       0.0        35.0       0.0       0.0  ...    0.047666    0.092142
# 3      40.0      2430.0      57.0      16.0  ...    0.475746    0.405178
# 4       2.0       163.0       0.0       2.0  ...    0.140375    0.416333
#
#    perbac1956  persup1956  perbac1957  persup1957  perbac1958  persup1958  \
# ...

# %%
df.describe()
# Out:
#           nodiph1962      bach1962      suph1962     nodipf1962      bacf1962  \
# count   37728.000000  37728.000000  37728.000000   37728.000000  37728.000000
# mean      326.638968     10.516036     10.792886     372.345155     10.641036
# std      2095.527632     98.368516    144.876777    2627.753248    114.148091
# min         0.000000      0.000000      0.000000       0.000000      0.000000
# 25%        48.000000      0.000000      0.000000      50.000000      0.000000
# 50%        96.000000      2.000000      0.000000      97.000000      0.000000
# 75%       197.000000      4.000000      2.000000     209.000000      2.000000
# max    220015.000000   8447.000000  11937.000000  263314.000000   9317.000000
#
#            supf1962     nodiph1968      bach1968      suph1968     nodipf1968  \
# count  37728.000000   37728.000000  37728.000000  37728.000000   37728.000000
# mean       3.851622     325.345632     20.932782     19.602417     384.291349
# ...

# %%
col_2017 = []
for c in df.columns:
  if '2017' in c:
    col_2017.append(c) 

print(col_2017)
# Out:
# ['nodiph2017', 'bach2017', 'suph2017', 'nodipf2017', 'bacf2017', 'supf2017', 'nodip2017', 'bac2017', 'sup2017', 'pbac2017', 'perbac2017', 'psup2017', 'persup2017']

# %%
for c in col_2017:
    print(c, ':', df[c].isna().sum())
# Out:
# nodiph2017 : 0
# bach2017 : 0
# suph2017 : 0
# nodipf2017 : 0
# bacf2017 : 0
# supf2017 : 0
# nodip2017 : 0
# bac2017 : 0
# sup2017 : 0
# pbac2017 : 2755
# perbac2017 : 0
# psup2017 : 2755
# persup2017 : 0
